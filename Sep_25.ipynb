# %%
import pandas as pd
from pathlib import Path

# %%
csvpath = Path("03-Class-Activities_03-Python-Pandas_3.2-Meet-Pandas_07-Three-Year-Loans_Resources_loans.csv")
loans_csv = pd.read_csv(csvpath)
loans_csv.head(10)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  installment  \
# 0      10000        10000          10000.0  36 months    0.1033       324.23
# 1       4000         4000           4000.0  36 months    0.2340       155.68
# 2       5000         5000           5000.0  36 months    0.1797       180.69
# 3       9600         9600           9600.0  36 months    0.1298       323.37
# 4       2500         2500           2500.0  36 months    0.1356        84.92
# 5      30000        30000          30000.0  60 months    0.1894       777.23
# 6      23000        23000          23000.0  60 months    0.2089       620.81
# 7      32075        32075          32075.0  60 months    0.1180       710.26
# 8       8000         8000           8000.0  36 months    0.2340       311.35
# 9      10000        10000          10000.0  60 months    0.1992       264.50
#
#   grade sub_grade           emp_title emp_length home_ownership  annual_inc  \
# ...

# %%
loans_csv.describe(include="all")
# Out:
#             loan_amnt    funded_amnt  funded_amnt_inv       term  \
# count   128412.000000  128412.000000    128412.000000     128412
# unique            NaN            NaN              NaN          2
# top               NaN            NaN              NaN  36 months
# freq              NaN            NaN              NaN      88179
# mean     15971.321021   15971.321021     15968.498166        NaN
# std      10150.384233   10150.384233     10152.168970        NaN
# min       1000.000000    1000.000000       725.000000        NaN
# 25%       8000.000000    8000.000000      8000.000000        NaN
# 50%      14000.000000   14000.000000     14000.000000        NaN
# 75%      21600.000000   21600.000000     21600.000000        NaN
# max      40000.000000   40000.000000     40000.000000        NaN
#
#              int_rate    installment   grade sub_grade emp_title emp_length  \
# count   128412.000000  128412.000000  128412    128412    107465     116708
# ...

# %%
filtered_df = loans_csv.iloc[:, [0, 3, 4, 8, 11, 16]]
filtered_df.head(10)
# Out:
#    loan_amnt       term  int_rate           emp_title  annual_inc  \
# 0      10000  36 months    0.1033                 NaN    280000.0
# 1       4000  36 months    0.2340            Security     90000.0
# 2       5000  36 months    0.1797      Administrative     59280.0
# 3       9600  36 months    0.1298                 NaN     35704.0
# 4       2500  36 months    0.1356                Chef     55000.0
# 5      30000  60 months    0.1894         Postmaster      90000.0
# 6      23000  60 months    0.2089            Operator     68107.0
# 7      32075  60 months    0.1180  Nursing Supervisor    150000.0
# 8       8000  36 months    0.2340             Manager     43000.0
# 9      10000  60 months    0.1992    Material Handler     80000.0
#
#               purpose
# 0  debt_consolidation
# 1  debt_consolidation
# 2  debt_consolidation
# 3    home_improvement
# 4  debt_consolidation
# 5  debt_consolidation
# 6  debt_consolidation
# 7         credit_card
# 8  debt_consolidation
# ...

# %%
term_df = filtered_df.loc[filtered_df['term'] == '36 months'].copy()
term_df.head()
# Out:
#    loan_amnt       term  int_rate       emp_title  annual_inc  \
# 0      10000  36 months    0.1033             NaN    280000.0
# 1       4000  36 months    0.2340        Security     90000.0
# 2       5000  36 months    0.1797  Administrative     59280.0
# 3       9600  36 months    0.1298             NaN     35704.0
# 4       2500  36 months    0.1356            Chef     55000.0
#
#               purpose
# 0  debt_consolidation
# 1  debt_consolidation
# 2  debt_consolidation
# 3    home_improvement
# 4  debt_consolidation

# %%
term_df.loc[term_df['term'] == '36 months', 'term'] = '3 years'
term_df.head(5)
# Out:
#    loan_amnt     term  int_rate       emp_title  annual_inc  \
# 0      10000  3 years    0.1033             NaN    280000.0
# 1       4000  3 years    0.2340        Security     90000.0
# 2       5000  3 years    0.1797  Administrative     59280.0
# 3       9600  3 years    0.1298             NaN     35704.0
# 4       2500  3 years    0.1356            Chef     55000.0
#
#               purpose
# 0  debt_consolidation
# 1  debt_consolidation
# 2  debt_consolidation
# 3    home_improvement
# 4  debt_consolidation

# %%
# term_df.loc[term_df['emp_title'].isnull(), 'emp_title'] = 'Unknown'
# term_df.head()
# Out:
#    loan_amnt     term  int_rate       emp_title  annual_inc  \
# 0      10000  3 years    0.1033         Unknown    280000.0
# 1       4000  3 years    0.2340        Security     90000.0
# 2       5000  3 years    0.1797  Administrative     59280.0
# 3       9600  3 years    0.1298         Unknown     35704.0
# 4       2500  3 years    0.1356            Chef     55000.0
#
#               purpose
# 0  debt_consolidation
# 1  debt_consolidation
# 2  debt_consolidation
# 3    home_improvement
# 4  debt_consolidation

# %%
term_df['emp_title'].fillna("Unknown")
term_df.head()
# Out:
#    loan_amnt     term  int_rate       emp_title  annual_inc  \
# 0      10000  3 years    0.1033         Unknown    280000.0
# 1       4000  3 years    0.2340        Security     90000.0
# 2       5000  3 years    0.1797  Administrative     59280.0
# 3       9600  3 years    0.1298         Unknown     35704.0
# 4       2500  3 years    0.1356            Chef     55000.0
#
#               purpose
# 0  debt_consolidation
# 1  debt_consolidation
# 2  debt_consolidation
# 3    home_improvement
# 4  debt_consolidation

# %%
term_df['emp_title'].value_counts()
# Out:
# Unknown                           15669
# Teacher                            1433
# Manager                            1207
# Registered Nurse                    672
# Driver                              654
#                                   ...
# Adult entertainer                     1
# transportation consultant             1
# Tool and Die                          1
# Senior Clerk Specialist               1
# Account Recievable specialist         1
# Name: emp_title, Length: 31470, dtype: int64

# %%
term_df['purpose'].value_counts()
# Out:
# debt_consolidation    45456
# credit_card           24780
# other                  5836
# home_improvement       5446
# major_purchase         1795
# medical                1245
# car                     838
# small_business          828
# vacation                749
# house                   596
# moving                  547
# renewable_energy         63
# Name: purpose, dtype: int64

# %%
term_df.loc[term_df['annual_inc'] > 80000].describe()
# Out:
#           loan_amnt      int_rate    annual_inc
# count  29748.000000  29748.000000  2.974800e+04
# mean   18240.116142      0.114116  1.389634e+05
# std    10991.909117      0.048067  1.752361e+05
# min     1000.000000      0.060000  8.000100e+04
# 25%    10000.000000      0.075600  9.500000e+04
# 50%    15700.000000      0.104700  1.120000e+05
# 75%    25000.000000      0.144700  1.500000e+05
# max    40000.000000      0.309400  9.000000e+06

# %%
term_df.loc[term_df['annual_inc'] < 80000].describe()
# Out:
#           loan_amnt      int_rate    annual_inc
# count  56015.000000  56015.000000  56015.000000
# mean   10607.487727      0.124268  49372.805964
# std     7318.791900      0.049137  16669.098821
# min     1000.000000      0.060000      0.000000
# 25%     5000.000000      0.081900  37000.000000
# 50%     9600.000000      0.113100  50000.000000
# 75%    14000.000000      0.150200  62635.500000
# max    40000.000000      0.309900  79999.000000

# %%
term_df.loc[term_df['annual_inc'] > 80000].mean()
# Out:
# loan_amnt      18240.116142
# int_rate           0.114116
# annual_inc    138963.373790
# dtype: float64

# %%
term_df.loc[term_df['annual_inc'] < 80000].mean()
# Out:
# loan_amnt     10607.487727
# int_rate          0.124268
# annual_inc    49372.805964
# dtype: float64

# %%
# %matplotlib inline

csvpath = Path('03-Class-Activities_03-Python-Pandas_3.2-Meet-Pandas_09-Market-Analysis_Resources_sp500_companies.csv')
sp500_companies_csv = pd.read_csv(csvpath)
sp500_companies_csv.head()
# Out:
#   Symbol                 Name                  Sector   Price  Price/Earnings  \
# 0    MMM           3M Company             Industrials  222.89           24.31
# 1    AOS      A.O. Smith Corp             Industrials   60.24           27.76
# 2    ABT  Abbott Laboratories             Health Care   56.27           22.51
# 3   ABBV          AbbVie Inc.             Health Care  108.48           19.41
# 4    ACN        Accenture plc  Information Technology  150.51           25.47
#
#    Dividend Yield  Earnings/Share  52 Week Low  52 Week High    Market Cap  \
# 0        2.332862            7.92       259.77       175.490  138721055226
# 1        1.147959            1.70        68.39        48.925   10783419933
# 2        1.908982            0.26        64.60        42.280  102121042306
# 3        2.499560            3.29       125.86        60.050  181386347059
# 4        1.714470            5.44       162.60       114.820   98765855553
#
#          EBITDA  Price/Sales  Price/Book  \
# ...

# %%
sp500_companies_csv['Sector'].value_counts().plot(kind='pie')

# %%
sp500_companies_csv.columns
# Out:
# Index(['Symbol', 'Name', 'Sector', 'Price', 'Price/Earnings', 'Dividend Yield',
#        'Earnings/Share', '52 Week Low', '52 Week High', 'Market Cap', 'EBITDA',
#        'Price/Sales', 'Price/Book', 'SEC Filings'],
#       dtype='object')

# %%
market_cap = sp500_companies_csv.loc[:, ['Symbol','Market Cap']]
market_cap.set_index(market_cap['Symbol'], inplace=True)
market_cap.drop(columns=['Symbol'], inplace=True)
top_20_market_cap = market_cap.nlargest(28, ['Market Cap'])
top_20_market_cap
# Out:
#           Market Cap
# Symbol
# AAPL    809508034020
# GOOGL   733823966137
# GOOG    728535558140
# MSFT    689978437468
# AMZN    685873374731
# FB      523423036576
# JPM     386613611000
# JNJ     353062464971
# XOM     326148660000
# BAC     321478200969
# WMT     304680931618
# WFC     281463620775
# V       270038723213
# BRK.B   261401203633
# T       226713270000
# HD      223378633329
# CVX     218978820159
# UNH     218834811333
# INTC    211536000000
# PFE     208505541949
# VZ      208092277044
# PG      206318943299
# BA      205617405233
# ORCL    202302349740
# CSCO    199425716482
# C       192709302000
# KO      189855335601
# MA      187102014193

# %%
top_20_market_cap.plot(kind='bar', title='Top 20 Market Cap Companies (in billions)', figsize=(20,10))

# %%
sp500_companies_csv.plot(kind='scatter', x='Earnings/Share', y='Price')

# %%
csvpath = Path('03-Class-Activities_03-Python-Pandas_3.3-Risk-and-Returns-Over-Time_02-Out-of-Sorts_Resources_bb_stock_data.csv')
bb_csv = pd.read_csv(csvpath)
bb_csv.head()
# Out:
#      Date  Close
# 0  1/2/19   9.64
# 1  1/3/19   9.29
# 2  1/4/19   9.67
# 3  1/7/19   9.88
# 4  1/8/19   9.82

# %%
import pandas as pd
from pathlib import Path
bb_csv.set_index(bb_csv['Date'], inplace=True)
bb_csv.head()
# Out:
#           Date  Close
# Date
# 1/2/19  1/2/19   9.64
# 1/3/19  1/3/19   9.29
# 1/4/19  1/4/19   9.67
# 1/7/19  1/7/19   9.88
# 1/8/19  1/8/19   9.82

# %%
bb_csv.drop(columns=['Date'])
# Out:
#           Close
# Date
# 1/2/19     9.64
# 1/3/19     9.29
# 1/4/19     9.67
# 1/7/19     9.88
# 1/8/19     9.82
# ...         ...
# 12/20/19   8.57
# 12/23/19   8.53
# 12/24/19   8.37
# 12/27/19   8.44
# 12/30/19   8.39
#
# [250 rows x 1 columns]

# %%
daily_returns = bb_csv.pct_change()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     120     if result is None:
# --> 121         result = _evaluate_standard(op, op_str, a, b)
#     122
#
# ...

# %%
bb_csv.isnull().mean()*100
# Out:
# Date     0.0
# Close    0.0
# dtype: float64

# %%
bb_csv.pct_change()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     120     if result is None:
# --> 121         result = _evaluate_standard(op, op_str, a, b)
#     122
#
# ...
